# %% [markdown]
# # Keras API Project
#
# ## The Data
#
# We will be using a subset of the LendingClub DataSet obtained from Kaggle: https://www.kaggle.com/wordsforthewise/lending-club
#
# ## NOTE: Do not download the full zip from the link! We have a special version of this file that has some extra feature engineering.
#
# LendingClub is a US peer-to-peer lending company, headquartered in San Francisco, California.[3] It was the first peer-to-peer lender to register its offerings as securities with the Securities and Exchange Commission (SEC), and to offer loan trading on a secondary market. LendingClub is the world's largest peer-to-peer lending platform.
#
# ### Our Goal
#
# Given historical data on loans given out with information on whether or not the borrower defaulted (charge-off), can we build a model that can predict whether or nor a borrower will pay back their loan? This way in the future when we get a new potential customer we can assess whether or not they are likely to pay back the loan.
#
# The "loan_status" column contains our label.
#
# ### Data Overview

# %% [markdown]
# ----
# -----
# There are many LendingClub data sets on Kaggle. Here is the information on this particular data set:
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>LoanStatNew</th>
#       <th>Description</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>loan_amnt</td>
#       <td>The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>term</td>
#       <td>The number of payments on the loan. Values are in months and can be either 36 or 60.</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>int_rate</td>
#       <td>Interest Rate on the loan</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>installment</td>
#       <td>The monthly payment owed by the borrower if the loan originates.</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>grade</td>
#       <td>LC assigned loan grade</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>sub_grade</td>
#       <td>LC assigned loan subgrade</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>emp_title</td>
#       <td>The job title supplied by the Borrower when applying for the loan.*</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>emp_length</td>
#       <td>Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>home_ownership</td>
#       <td>The home ownership status provided by the borrower during registration or obtained from the credit report. Our values are: RENT, OWN, MORTGAGE, OTHER</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>annual_inc</td>
#       <td>The self-reported annual income provided by the borrower during registration.</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>verification_status</td>
#       <td>Indicates if income was verified by LC, not verified, or if the income source was verified</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>issue_d</td>
#       <td>The month which the loan was funded</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>loan_status</td>
#       <td>Current status of the loan</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>purpose</td>
#       <td>A category provided by the borrower for the loan request.</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>title</td>
#       <td>The loan title provided by the borrower</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>zip_code</td>
#       <td>The first 3 numbers of the zip code provided by the borrower in the loan application.</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>addr_state</td>
#       <td>The state provided by the borrower in the loan application</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>dti</td>
#       <td>A ratio calculated using the borrower’s total monthly debt payments on the total debt obligations, excluding mortgage and the requested LC loan, divided by the borrower’s self-reported monthly income.</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>earliest_cr_line</td>
#       <td>The month the borrower's earliest reported credit line was opened</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>open_acc</td>
#       <td>The number of open credit lines in the borrower's credit file.</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>pub_rec</td>
#       <td>Number of derogatory public records</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>revol_bal</td>
#       <td>Total credit revolving balance</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>revol_util</td>
#       <td>Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.</td>
#     </tr>
#     <tr>
#       <th>23</th>
#       <td>total_acc</td>
#       <td>The total number of credit lines currently in the borrower's credit file</td>
#     </tr>
#     <tr>
#       <th>24</th>
#       <td>initial_list_status</td>
#       <td>The initial listing status of the loan. Possible values are – W, F</td>
#     </tr>
#     <tr>
#       <th>25</th>
#       <td>application_type</td>
#       <td>Indicates whether the loan is an individual application or a joint application with two co-borrowers</td>
#     </tr>
#     <tr>
#       <th>26</th>
#       <td>mort_acc</td>
#       <td>Number of mortgage accounts.</td>
#     </tr>
#     <tr>
#       <th>27</th>
#       <td>pub_rec_bankruptcies</td>
#       <td>Number of public record bankruptcies</td>
#     </tr>
#   </tbody>
# </table>
#
# ---
# ----

# %% [markdown]
# ## Starter Code
#
# #### Note: We also provide feature information on the data as a .csv file for easy lookup throughout the notebook:

# %%
import pandas as pd

# %%
data_info = pd.read_csv('lending_club_info.csv',index_col='LoanStatNew')

# %%
print(data_info.loc['revol_util']['Description'])
# Out:
# Revolving line utilization rate, or the amount of credit the borrower is using relative to all available revolving credit.

# %%
def feat_info(col_name):
    print(data_info.loc[col_name]['Description'])

# %%
feat_info('mort_acc')
# Out:
# Number of mortgage accounts.

# %% [markdown]
# ## Loading the data and other imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# might be needed depending on your version of Jupyter
# %matplotlib inline

# %%
df = pd.read_csv('lending_club_loan_two.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 27 columns):
# loan_amnt               396030 non-null float64
# term                    396030 non-null object
# int_rate                396030 non-null float64
# installment             396030 non-null float64
# grade                   396030 non-null object
# sub_grade               396030 non-null object
# emp_title               373103 non-null object
# emp_length              377729 non-null object
# home_ownership          396030 non-null object
# annual_inc              396030 non-null float64
# verification_status     396030 non-null object
# issue_d                 396030 non-null object
# loan_status             396030 non-null object
# purpose                 396030 non-null object
# title                   394275 non-null object
# dti                     396030 non-null float64
# earliest_cr_line        396030 non-null object
# open_acc                396030 non-null float64
# pub_rec                 396030 non-null float64
# revol_bal               396030 non-null float64
# revol_util              395754 non-null float64
# total_acc               396030 non-null float64
# initial_list_status     396030 non-null object
# application_type        396030 non-null object
# mort_acc                358235 non-null float64
# pub_rec_bankruptcies    395495 non-null float64
# address                 396030 non-null object
# dtypes: float64(12), object(15)
# memory usage: 81.6+ MB

# %% [markdown]
# # Project Tasks
#
#
#
# # Section 1: Exploratory Data Analysis
#
# **OVERALL GOAL: Get an understanding for which variables are important, view summary statistics, and visualize the data**

# %% [markdown]
# **TASK: Since we will be attempting to predict loan_status, create a countplot as shown below.**

# %%
sns.countplot(x="loan_status", data=df)
plt.xlabel("Loan Status")
# Out:
# Text(0.5, 0, 'Loan Status')

# %% [markdown]
# **TASK: Create a histogram of the loan_amnt column.**

# %%
plt.figure(figsize=(20,8))
sns.histplot(x="loan_amnt", data=df, kde=False)
plt.xlabel("Loan Amount")
plt.xlim(0,40000)
# Out:
# (0.0, 40000.0)

# %% [markdown]
# **TASK: Let's explore correlation between the continuous feature variables. Calculate the correlation between all continuous numeric variables using .corr() method.**

# %%
df.corr()
# Out:
#                       loan_amnt  int_rate  installment  annual_inc       dti  \
# loan_amnt              1.000000  0.168921     0.953929    0.336887  0.016636
# int_rate               0.168921  1.000000     0.162758   -0.056771  0.079038
# installment            0.953929  0.162758     1.000000    0.330381  0.015786
# annual_inc             0.336887 -0.056771     0.330381    1.000000 -0.081685
# dti                    0.016636  0.079038     0.015786   -0.081685  1.000000
# open_acc               0.198556  0.011649     0.188973    0.136150  0.136181
# pub_rec               -0.077779  0.060986    -0.067892   -0.013720 -0.017639
# revol_bal              0.328320 -0.011280     0.316455    0.299773  0.063571
# revol_util             0.099911  0.293659     0.123915    0.027871  0.088375
# total_acc              0.223886 -0.036404     0.202430    0.193023  0.102128
# mort_acc               0.222315 -0.082583     0.193694    0.236320 -0.025439
# pub_rec_bankruptcies  -0.106539  0.057450    -0.098628   -0.050162 -0.014558
#
#                       open_acc   pub_rec  revol_bal  revol_util  total_acc  \
# loan_amnt             0.198556 -0.077779   0.328320    0.099911   0.223886
# int_rate              0.011649  0.060986  -0.011280    0.293659  -0.036404
# installment           0.188973 -0.067892   0.316455    0.123915   0.202430
# annual_inc            0.136150 -0.013720   0.299773    0.027871   0.193023
# dti                   0.136181 -0.017639   0.063571    0.088375   0.102128
# open_acc              1.000000 -0.018392   0.221192   -0.131420   0.680728
# pub_rec              -0.018392  1.000000  -0.101664   -0.075910   0.019723
# revol_bal             0.221192 -0.101664   1.000000    0.226346   0.191616
# revol_util           -0.131420 -0.075910   0.226346    1.000000  -0.104273
# total_acc             0.680728  0.019723   0.191616   -0.104273   1.000000
# mort_acc              0.109205  0.011552   0.194925    0.007514   0.381072
# pub_rec_bankruptcies -0.027732  0.699408  -0.124532   -0.086751   0.042035
#
#                       mort_acc  pub_rec_bankruptcies
# loan_amnt             0.222315             -0.106539
# int_rate             -0.082583              0.057450
# installment           0.193694             -0.098628
# annual_inc            0.236320             -0.050162
# dti                  -0.025439             -0.014558
# open_acc              0.109205             -0.027732
# pub_rec               0.011552              0.699408
# revol_bal             0.194925             -0.124532
# revol_util            0.007514             -0.086751
# total_acc             0.381072              0.042035
# mort_acc              1.000000              0.027239
# pub_rec_bankruptcies  0.027239              1.000000

# %% [markdown]
# **TASK: Visualize this using a heatmap. **
#
# * [Heatmap info](https://seaborn.pydata.org/generated/seaborn.heatmap.html#seaborn.heatmap)
# * [Help with resizing](https://stackoverflow.com/questions/56942670/matplotlib-seaborn-first-and-last-row-cut-in-half-of-heatmap-plot)

# %%
plt.figure(figsize=(16,8))
sns.heatmap(df.corr(), cmap="viridis", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# **TASK: You should have noticed almost perfect correlation with the "installment" feature. Explore this feature further. Print out their descriptions and perform a scatterplot between them. Does this relationship make sense to you? Do you think there is duplicate information here?**

# %%
feat_info("installment")
# Out:
# The monthly payment owed by the borrower if the loan originates.

# %%
feat_info("loan_amnt")
# Out:
# The listed amount of the loan applied for by the borrower. If at some point in time, the credit department reduces the loan amount, then it will be reflected in this value.

# %%
plt.figure(figsize=(16,8))
sns.scatterplot(x="installment", y="loan_amnt", data=df)
# Out:
# <AxesSubplot:xlabel='installment', ylabel='loan_amnt'>

# %% [markdown]
# **TASK: Create a boxplot showing the relationship between the loan_status and the Loan Amount.**

# %%
sns.boxplot(x="loan_status",y="loan_amnt", data=df)
# Out:
# <AxesSubplot:xlabel='loan_status', ylabel='loan_amnt'>

# %% [markdown]
# **TASK: Calculate the summary statistics for the loan amount, grouped by the loan_status.**

# %%
df.groupby("loan_status")["loan_amnt"].describe()
# Out:
#                 count          mean          std     min     25%      50%  \
# loan_status
# Charged Off   77673.0  15126.300967  8505.090557  1000.0  8525.0  14000.0
# Fully Paid   318357.0  13866.878771  8302.319699   500.0  7500.0  12000.0
#
#                  75%      max
# loan_status
# Charged Off  20000.0  40000.0
# Fully Paid   19225.0  40000.0

# %% [markdown]
# **TASK: Let's explore the Grade and SubGrade columns that LendingClub attributes to the loans. What are the unique possible grades and subgrades?**

# %%
sorted(df["grade"].unique())
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G']

# %%
sorted(df["sub_grade"].unique())
# Out:
# ['A1',
#  'A2',
#  'A3',
#  'A4',
#  'A5',
#  'B1',
#  'B2',
#  'B3',
#  'B4',
#  'B5',
#  'C1',
#  'C2',
#  'C3',
#  'C4',
#  'C5',
#  'D1',
#  'D2',
#  'D3',
#  'D4',
#  'D5',
#  'E1',
#  'E2',
#  'E3',
#  'E4',
#  'E5',
#  'F1',
#  'F2',
#  'F3',
#  'F4',
#  'F5',
#  'G1',
#  'G2',
#  'G3',
#  'G4',
#  'G5']

# %% [markdown]
# **TASK: Create a countplot per grade. Set the hue to the loan_status label.**

# %%
sns.countplot(x="grade",data=df, hue="loan_status", order=sorted(df["grade"].unique()))
# Out:
# <AxesSubplot:xlabel='grade', ylabel='count'>

# %% [markdown]
# **TASK: Display a count plot per subgrade. You may need to resize for this plot and [reorder](https://seaborn.pydata.org/generated/seaborn.countplot.html#seaborn.countplot) the x axis. Feel free to edit the color palette. Explore both all loans made per subgrade as well being separated based on the loan_status. After creating this plot, go ahead and create a similar plot, but set hue="loan_status"**

# %%
plt.figure(figsize=(12,4))
sns.countplot(x="sub_grade",data=df, order=sorted(df["sub_grade"].unique()),palette="viridis")
# Out:
# <AxesSubplot:xlabel='sub_grade', ylabel='count'>

# %% [markdown]
# **TASK: It looks like F and G subgrades don't get paid back that often. Isloate those and recreate the countplot just for those subgrades.**

# %%
df_F_G=df[(df["grade"]=="F") | (df["grade"]=="G")]

# %%
plt.figure(figsize=(12,4))
sns.countplot(x="sub_grade",data=df_F_G, order=sorted(df_F_G["sub_grade"].unique()),hue="loan_status")
# Out:
# <AxesSubplot:xlabel='sub_grade', ylabel='count'>

# %% [markdown]
# **TASK: Create a new column called 'loan_repaid' which will contain a 1 if the loan status was "Fully Paid" and a 0 if it was "Charged Off".**

# %%
df["loan_repaid"]=df["loan_status"].apply(lambda x: 1 if (x=="Fully Paid") else 0)

# %%
df[["loan_repaid", "loan_status"]].head()
# Out:
#    loan_repaid  loan_status
# 0            1   Fully Paid
# 1            1   Fully Paid
# 2            1   Fully Paid
# 3            1   Fully Paid
# 4            0  Charged Off

# %% [markdown]
# Create a bar plot showing the correlation of the numeric features to the new loan_repaid column. [Helpful Link](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html)**

# %%
df.corr()["loan_repaid"].sort_values()[:-1].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---
# ---
# # Section 2: Data PreProcessing
#
# **Section Goals: Remove or fill any missing data. Remove unnecessary or repetitive features. Convert categorical string features to dummy variables.**

# %%
df.head()
# Out:
#    loan_amnt        term  int_rate  installment grade sub_grade  \
# 0    10000.0   36 months     11.44       329.48     B        B4
# 1     8000.0   36 months     11.99       265.68     B        B5
# 2    15600.0   36 months     10.49       506.97     B        B3
# 3     7200.0   36 months      6.49       220.65     A        A2
# 4    24375.0   60 months     17.27       609.33     C        C5
#
#                  emp_title emp_length home_ownership  annual_inc  ... pub_rec  \
# 0                Marketing  10+ years           RENT    117000.0  ...     0.0
# 1          Credit analyst     4 years       MORTGAGE     65000.0  ...     0.0
# 2             Statistician   < 1 year           RENT     43057.0  ...     0.0
# 3          Client Advocate    6 years           RENT     54000.0  ...     0.0
# 4  Destiny Management Inc.    9 years       MORTGAGE     55000.0  ...     0.0
#
#   revol_bal revol_util total_acc initial_list_status  application_type  \
# 0   36369.0       41.8      25.0                   w        INDIVIDUAL
# 1   20131.0       53.3      27.0                   f        INDIVIDUAL
# 2   11987.0       92.2      26.0                   f        INDIVIDUAL
# 3    5472.0       21.5      13.0                   f        INDIVIDUAL
# 4   24584.0       69.8      43.0                   f        INDIVIDUAL
#
#   mort_acc  pub_rec_bankruptcies  \
# 0      0.0                   0.0
# 1      3.0                   0.0
# 2      0.0                   0.0
# 3      0.0                   0.0
# 4      1.0                   0.0
#
#                                            address  loan_repaid
# 0     0174 Michelle Gateway\nMendozaberg, OK 22690            1
# 1  1076 Carney Fort Apt. 347\nLoganmouth, SD 05113            1
# 2  87025 Mark Dale Apt. 269\nNew Sabrina, WV 05113            1
# 3            823 Reid Ford\nDelacruzside, MA 00813            1
# 4             679 Luna Roads\nGreggshire, VA 11650            0
#
# [5 rows x 28 columns]

# %% [markdown]
# # Missing Data
#
# **Let's explore this missing data columns. We use a variety of factors to decide whether or not they would be useful, to see if we should keep, discard, or fill in the missing data.**

# %% [markdown]
# **TASK: What is the length of the dataframe?**

# %%
len(df)
# Out:
# 396030

# %% [markdown]
# **TASK: Create a Series that displays the total count of missing values per column.**

# %%
df.isna().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# emp_title               22927
# emp_length              18301
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                    1755
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# loan_repaid                 0
# dtype: int64

# %% [markdown]
# **TASK: Convert this Series to be in term of percentage of the total DataFrame**

# %%
df.isna().sum()/len(df)*100
# Out:
# loan_amnt               0.000000
# term                    0.000000
# int_rate                0.000000
# installment             0.000000
# grade                   0.000000
# sub_grade               0.000000
# emp_title               5.789208
# emp_length              4.621115
# home_ownership          0.000000
# annual_inc              0.000000
# verification_status     0.000000
# issue_d                 0.000000
# loan_status             0.000000
# purpose                 0.000000
# title                   0.443148
# dti                     0.000000
# earliest_cr_line        0.000000
# open_acc                0.000000
# pub_rec                 0.000000
# revol_bal               0.000000
# revol_util              0.069692
# total_acc               0.000000
# initial_list_status     0.000000
# application_type        0.000000
# mort_acc                9.543469
# pub_rec_bankruptcies    0.135091
# address                 0.000000
# loan_repaid             0.000000
# dtype: float64

# %%
plt.figure(figsize=(12,4))
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <AxesSubplot:>

# %% [markdown]
# **TASK: Let's examine emp_title and emp_length to see whether it will be okay to drop them. Print out their feature information using the feat_info() function from the top of this notebook.**

# %%
feat_info("emp_title")
# Out:
# The job title supplied by the Borrower when applying for the loan.*

# %%
feat_info("emp_length")
# Out:
# Employment length in years. Possible values are between 0 and 10 where 0 means less than one year and 10 means ten or more years.

# %% [markdown]
# **TASK: How many unique employment job titles are there?**

# %%
df["emp_title"].nunique()
# Out:
# 173105

# %%
df["emp_title"].value_counts()
# Out:
# Teacher                                 4389
# Manager                                 4250
# Registered Nurse                        1856
# RN                                      1846
# Supervisor                              1830
#                                         ...
# Executive Operations Officer               1
# Contemporary Jewish Museum                 1
# Director of Manufacturing Operations       1
# Class A Toolmaker                          1
# Supervisor/Housing Specialist              1
# Name: emp_title, Length: 173105, dtype: int64

# %%
plt.figure(figsize=(16,4))
sns.countplot(x="emp_title",data=df,order=df["emp_title"].value_counts().index[:10], hue="loan_status")
# Out:
# <AxesSubplot:xlabel='emp_title', ylabel='count'>

# %%
emp_title_10 = list(df["emp_title"].value_counts()[df["emp_title"].value_counts()>=10].index)

# %%
df["emp_title"].value_counts()[df["emp_title"].value_counts()>=10].sum()/len(df)*100
# Out:
# 38.467540337853194

# %% [markdown]
# **TASK: Modify the name of less frequent jobs and missing ones.**

# %%
df["emp_title"]=df["emp_title"].apply(lambda x: x if x in emp_title_10 else ("Missing Job Info" if pd.isnull(x) else "Other Jobs"  ))

# %% [markdown]
# **Create Tiers for the job titles**

# %%
emp_title_mean_income=df.groupby("emp_title").mean()['annual_inc'].drop(["Missing Job Info", "Other Jobs"])
emp_title_mean_income.describe(percentiles=[0.01,0.05,0.25,0.5,0.75,0.95,0.99])
# Out:
# count      3154.000000
# mean      76128.603916
# std       31459.119119
# min       25842.357143
# 1%        34177.692308
# 5%        40495.197727
# 25%       56162.541364
# 50%       69887.321429
# 75%       88146.686869
# 95%      130457.820303
# 99%      181602.512952
# max      564847.076923
# Name: annual_inc, dtype: float64

# %%
tier1=list(emp_title_mean_income[emp_title_mean_income>180000].index)
tier2=list(emp_title_mean_income[(emp_title_mean_income<=180000) & (emp_title_mean_income>130000)].index)
tier3=list(emp_title_mean_income[(emp_title_mean_income<=130000) & (emp_title_mean_income>90000)].index)
tier4=list(emp_title_mean_income[(emp_title_mean_income<=90000) & (emp_title_mean_income>70000)].index)
tier5=list(emp_title_mean_income[(emp_title_mean_income<=70000) & (emp_title_mean_income>55000)].index)
tier6=list(emp_title_mean_income[(emp_title_mean_income<=55000) & (emp_title_mean_income>40000)].index)
tier7=list(emp_title_mean_income[(emp_title_mean_income<=40000) & (emp_title_mean_income>34000)].index)
tier8=list(emp_title_mean_income[(emp_title_mean_income<=34000)].index)
#tier9 is other jobs
#tier10 is missing values

# %%
df["job_tier"]=df["emp_title"].apply(lambda x: 1 if x in tier1 
                                      else (2 if x in tier2 
                                            else (3 if x in tier3
                                                 else ( 4 if x in tier4
                                                       else ( 5 if x in tier5
                                                             else (6 if x in tier6
                                                                  else (7 if x in tier7 
                                                                        else (8 if x in tier8
                                                                             else (9 if x=="Other Jobs" 
                                                                                  else 10)) )))))))

# %%
df=df.drop("emp_title", axis=1)

# %%
df.groupby("job_tier")["loan_repaid"].mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='job_tier'>

# %%
df.groupby("job_tier")["loan_repaid"].mean().describe()
# Out:
# count    10.000000
# mean      0.785519
# std       0.054219
# min       0.709069
# 25%       0.742262
# 50%       0.793477
# 75%       0.832763
# max       0.854839
# Name: loan_repaid, dtype: float64

# %% [markdown]
# **TASK: Create a count plot of the emp_length feature column. Challenge: Sort the order of the values.**

# %%
sorted(df["emp_length"].dropna().unique())
# Out:
# ['1 year',
#  '10+ years',
#  '2 years',
#  '3 years',
#  '4 years',
#  '5 years',
#  '6 years',
#  '7 years',
#  '8 years',
#  '9 years',
#  '< 1 year']

# %%
emp_length_order=['< 1 year',
                 '1 year',
                 '2 years',
                 '3 years',
                 '4 years',
                 '5 years',
                 '6 years',
                 '7 years',
                 '8 years',
                 '9 years',
                 '10+ years']

# %%
plt.figure(figsize=(12,4))
sns.countplot(x="emp_length",data=df, order=emp_length_order,palette="viridis")
# Out:
# <AxesSubplot:xlabel='emp_length', ylabel='count'>

# %% [markdown]
# **TASK: Plot out the countplot with a hue separating Fully Paid vs Charged Off**

# %%
plt.figure(figsize=(12,4))
sns.countplot(x="emp_length",data=df, order=emp_length_order,hue="loan_status")
# Out:
# <AxesSubplot:xlabel='emp_length', ylabel='count'>

# %% [markdown]
# This still doesn't really inform us if there is a strong relationship between employment length and being charged off, what we want is the percentage of full paids per category. Essentially informing us what percent of people per employment category paid back their loan. There are a multitude of ways to create this Series. Once you've created it, see if visualize it with a [bar plot](https://pandas.pydata.org/pandas-docs/version/0.23.4/generated/pandas.DataFrame.plot.html).

# %%
df.groupby("emp_length")["loan_repaid"].mean()
# Out:
# emp_length
# 1 year       0.800865
# 10+ years    0.815814
# 2 years      0.806738
# 3 years      0.804769
# 4 years      0.807615
# 5 years      0.807813
# 6 years      0.810806
# 7 years      0.805226
# 8 years      0.800240
# 9 years      0.799530
# < 1 year     0.793128
# Name: loan_repaid, dtype: float64

# %%
df.groupby("emp_length")["loan_repaid"].mean().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='emp_length'>

# %%
df.groupby("emp_length")["loan_repaid"].mean().describe()
# Out:
# count    11.000000
# mean      0.804777
# std       0.006153
# min       0.793128
# 25%       0.800553
# 50%       0.805226
# 75%       0.807714
# max       0.815814
# Name: loan_repaid, dtype: float64

# %% [markdown]
# **TASK: Charge off rates are extremely similar across all employment lengths. Go ahead and drop the emp_length column.**

# %%
df=df.drop("emp_length",axis=1)

# %% [markdown]
# **TASK: Revisit the DataFrame to see what feature columns still have missing data.**

# %%
df.isna().sum()
# Out:
# loan_amnt                   0
# term                        0
# int_rate                    0
# installment                 0
# grade                       0
# sub_grade                   0
# home_ownership              0
# annual_inc                  0
# verification_status         0
# issue_d                     0
# loan_status                 0
# purpose                     0
# title                    1755
# dti                         0
# earliest_cr_line            0
# open_acc                    0
# pub_rec                     0
# revol_bal                   0
# revol_util                276
# total_acc                   0
# initial_list_status         0
# application_type            0
# mort_acc                37795
# pub_rec_bankruptcies      535
# address                     0
# loan_repaid                 0
# job_tier                    0
# dtype: int64

# %% [markdown]
# **TASK: Review the title column vs the purpose column. Is this repeated information?**

# %%
df["purpose"].head(10)
# Out:
# 0              vacation
# 1    debt_consolidation
# 2           credit_card
# 3           credit_card
# 4           credit_card
# 5    debt_consolidation
# 6      home_improvement
# 7           credit_card
# 8    debt_consolidation
# 9    debt_consolidation
# Name: purpose, dtype: object

# %%
df['title'].head(10)
# Out:
# 0                   Vacation
# 1         Debt consolidation
# 2    Credit card refinancing
# 3    Credit card refinancing
# 4      Credit Card Refinance
# 5         Debt consolidation
# 6           Home improvement
# 7       No More Credit Cards
# 8         Debt consolidation
# 9         Debt Consolidation
# Name: title, dtype: object

# %% [markdown]
# **TASK: The title column is simply a string subcategory/description of the purpose column. Go ahead and drop the title column.**

# %%
df=df.drop("title",axis=1)

# %% [markdown]
# **TASK: Find out what the mort_acc feature represents**

# %%
feat_info("mort_acc")
# Out:
# Number of mortgage accounts.

# %%
df.corr()["mort_acc"].sort_values()[:-1].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df.corr()["revol_util"].sort_values()[:-1].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df.corr()["pub_rec_bankruptcies"].sort_values()[:-1].plot(kind="bar")
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Regression Imputation of Missing Continuous Values
#
#
# https://towardsdatascience.com/preprocessing-regression-imputation-of-missing-continuous-values-f612179bafb4

# %%
# explicitly require this experimental feature
from sklearn.experimental import enable_iterative_imputer  # noqa
# now you can import normally from sklearn.impute
from sklearn.impute import IterativeImputer
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.linear_model import BayesianRidge
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 26 columns):
# loan_amnt               396030 non-null float64
# term                    396030 non-null object
# int_rate                396030 non-null float64
# installment             396030 non-null float64
# grade                   396030 non-null object
# sub_grade               396030 non-null object
# home_ownership          396030 non-null object
# annual_inc              396030 non-null float64
# verification_status     396030 non-null object
# issue_d                 396030 non-null object
# loan_status             396030 non-null object
# purpose                 396030 non-null object
# dti                     396030 non-null float64
# earliest_cr_line        396030 non-null object
# open_acc                396030 non-null float64
# pub_rec                 396030 non-null float64
# revol_bal               396030 non-null float64
# revol_util              395754 non-null float64
# total_acc               396030 non-null float64
# initial_list_status     396030 non-null object
# application_type        396030 non-null object
# mort_acc                358235 non-null float64
# pub_rec_bankruptcies    395495 non-null float64
# address                 396030 non-null object
# loan_repaid             396030 non-null int64
# job_tier                396030 non-null int64
# dtypes: float64(12), int64(2), object(12)
# memory usage: 78.6+ MB

# %%
df_num = df[['mort_acc','total_acc','annual_inc','revol_util','int_rate','revol_bal']]
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 6 columns):
# mort_acc      358235 non-null float64
# total_acc     396030 non-null float64
# annual_inc    396030 non-null float64
# revol_util    395754 non-null float64
# int_rate      396030 non-null float64
# revol_bal     396030 non-null float64
# dtypes: float64(6)
# memory usage: 18.1 MB

# %%
df_num = df.select_dtypes(include=[np.float,np.int64]).drop("loan_repaid",axis=1)
df_num.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 13 columns):
# loan_amnt               396030 non-null float64
# int_rate                396030 non-null float64
# installment             396030 non-null float64
# annual_inc              396030 non-null float64
# dti                     396030 non-null float64
# open_acc                396030 non-null float64
# pub_rec                 396030 non-null float64
# revol_bal               396030 non-null float64
# revol_util              395754 non-null float64
# total_acc               396030 non-null float64
# mort_acc                358235 non-null float64
# pub_rec_bankruptcies    395495 non-null float64
# job_tier                396030 non-null int64
# dtypes: float64(12), int64(1)
# memory usage: 39.3 MB

# %%
imputer = IterativeImputer(BayesianRidge())
impute_data = pd.DataFrame(imputer.fit_transform(df_num),columns=df_num.columns)

# %%
df[impute_data.columns]=impute_data

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 396030 entries, 0 to 396029
# Data columns (total 26 columns):
# loan_amnt               396030 non-null float64
# term                    396030 non-null object
# int_rate                396030 non-null float64
# installment             396030 non-null float64
# grade                   396030 non-null object
# sub_grade               396030 non-null object
# home_ownership          396030 non-null object
# annual_inc              396030 non-null float64
# verification_status     396030 non-null object
# issue_d                 396030 non-null object
# loan_status             396030 non-null object
# purpose                 396030 non-null object
# dti                     396030 non-null float64
# earliest_cr_line        396030 non-null object
# open_acc                396030 non-null float64
# pub_rec                 396030 non-null float64
# revol_bal               396030 non-null float64
# revol_util              396030 non-null float64
# total_acc               396030 non-null float64
# initial_list_status     396030 non-null object
# application_type        396030 non-null object
# mort_acc                396030 non-null float64
# pub_rec_bankruptcies    396030 non-null float64
# address                 396030 non-null object
# loan_repaid             396030 non-null int64
# job_tier                396030 non-null float64
# dtypes: float64(13), int64(1), object(12)
# memory usage: 78.6+ MB

# %%
df = df.dropna()

# %%
df.isna().sum()
# Out:
# loan_amnt               0
# term                    0
# int_rate                0
# installment             0
# grade                   0
# sub_grade               0
# home_ownership          0
# annual_inc              0
# verification_status     0
# issue_d                 0
# loan_status             0
# purpose                 0
# dti                     0
# earliest_cr_line        0
# open_acc                0
# pub_rec                 0
# revol_bal               0
# revol_util              0
# total_acc               0
# initial_list_status     0
# application_type        0
# mort_acc                0
# pub_rec_bankruptcies    0
# address                 0
# loan_repaid             0
# job_tier                0
# dtype: int64

# %% [markdown]
# ## Categorical Variables and Dummy Variables
#
# **We're done working with the missing data! Now we just need to deal with the string values due to the categorical columns.**
#
# **TASK: List all the columns that are currently non-numeric. [Helpful Link](https://stackoverflow.com/questions/22470690/get-list-of-pandas-dataframe-columns-based-on-data-type)**
#
# [Another very useful method call](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.select_dtypes.html)

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['term', 'grade', 'sub_grade', 'home_ownership', 'verification_status',
#        'issue_d', 'loan_status', 'purpose', 'earliest_cr_line',
#        'initial_list_status', 'application_type', 'address'],
#       dtype='object')

# %% [markdown]
# ---
# **Let's now go through all the string features to see what we should do with them.**
#
# ---
#
#
# ### term feature
#
# **TASK: Convert the term feature into either a 36 or 60 integer numeric data type using .apply() or .map().**

# %%
df["term"].value_counts()
# Out:
#  36 months    302005
#  60 months     94025
# Name: term, dtype: int64

# %%
df['term']=df['term'].apply(lambda term: int(term[:3]))

# %% [markdown]
# ### grade feature
#
# **TASK: We already know grade is part of sub_grade, so just drop the grade feature.**

# %%
df=df.drop("grade", axis=1)

# %% [markdown]
# **TASK: Convert the subgrade into dummy variables. Then concatenate these new columns to the original dataframe. Remember to drop the original subgrade column and to add drop_first=True to your get_dummies call.**

# %%
sub_grade_dummies= pd.get_dummies(df['sub_grade'],drop_first=True)

# %%
df=df.drop("sub_grade",axis=1)

# %%
df=pd.concat([df, sub_grade_dummies],axis=1)

# %% [markdown]
# ### verification_status, application_type,initial_list_status,purpose
# **TASK: Convert these columns: ['verification_status', 'application_type','initial_list_status','purpose'] into dummy variables and concatenate them with the original dataframe. Set drop_first=True and to drop the original columns.**

# %%
dummies = pd.get_dummies(df[['job_tier','verification_status', 'application_type','initial_list_status','purpose' ]],drop_first=True)
df = df.drop(['job_tier','verification_status', 'application_type','initial_list_status','purpose'],axis=1)
df = pd.concat([df,dummies],axis=1)

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['home_ownership', 'issue_d', 'loan_status', 'earliest_cr_line',
#        'address'],
#       dtype='object')

# %% [markdown]
# ### home_ownership
# **TASK:Review the value_counts for the home_ownership column.**

# %%
df['home_ownership'].value_counts()
# Out:
# MORTGAGE    198348
# RENT        159790
# OWN          37746
# OTHER          112
# NONE            31
# ANY              3
# Name: home_ownership, dtype: int64

# %% [markdown]
# **TASK: Convert these to dummy variables, but [replace](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.replace.html) NONE and ANY with OTHER, so that we end up with just 4 categories, MORTGAGE, RENT, OWN, OTHER. Then concatenate them with the original dataframe. Remember to set drop_first=True and to drop the original columns.**

# %%
df['home_ownership']=df['home_ownership'].replace(["NONE","ANY"],value="OTHER")

# %%
dummies = pd.get_dummies(df['home_ownership'],drop_first=True)
df = df.drop('home_ownership',axis=1)
df = pd.concat([df,dummies],axis=1)

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['issue_d', 'loan_status', 'earliest_cr_line', 'address'], dtype='object')

# %% [markdown]
# ### address
# **TASK: Let's feature engineer a zip code column from the address in the data set. Create a column called 'zip_code' that extracts the zip code from the address column.**

# %%
df['zipcode']=df['address'].apply(lambda x: x[-5])

# %% [markdown]
# **TASK: Now make this zip_code column into dummy variables using pandas. Concatenate the result and drop the original zip_code column along with dropping the address column.**

# %%
dummies = pd.get_dummies(df['zipcode'],drop_first=True)
df = df.drop(['zipcode','address'],axis=1)
df = pd.concat([df,dummies],axis=1)

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['issue_d', 'loan_status', 'earliest_cr_line'], dtype='object')

# %% [markdown]
# ### issue_d
#
# **TASK: This would be data leakage, we wouldn't know beforehand whether or not a loan would be issued when using our model, so in theory we wouldn't have an issue_date, drop this feature.**

# %%
df = df.drop('issue_d',axis=1)

# %% [markdown]
# ### earliest_cr_line
# **TASK: This appears to be a historical time stamp feature. Extract the year from this feature using a .apply function, then convert it to a numeric feature. Set this new data to a feature column called 'earliest_cr_year'.Then drop the earliest_cr_line feature.**

# %%
df['earliest_cr_year']=df['earliest_cr_line'].apply(lambda x: x[-4:])

# %%
df=df.drop('earliest_cr_line',axis=1)

# %% [markdown]
# **TASK: drop the load_status column we created earlier, since its a duplicate of the loan_repaid column. We'll use the loan_repaid column since its already in 0s and 1s.**

# %%
df=df.drop('loan_status',axis=1)

# %%
df.select_dtypes(['object']).columns
# Out:
# Index(['earliest_cr_year'], dtype='object')

# %% [markdown]
# ## Train Test Split

# %% [markdown]
# **TASK: Import train_test_split from sklearn.**

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# **TASK: Set X and y variables to the .values of the features and label.**

# %%
X = df.drop('loan_repaid',axis=1)
y = df['loan_repaid']

# %% [markdown]
# ----
# ----
#
# # OPTIONAL
#
# ## Grabbing a Sample for Training Time
#
# ### OPTIONAL: Use .sample() to grab a sample of the 490k+ entries to save time on training. Highly recommended for lower RAM computers or if you are not using GPU.
#
# ----
# ----

# %%
# df = df.sample(frac=0.1,random_state=101)
print(len(df))
# Out:
# 396030

# %% [markdown]
# **TASK: Perform a train/test split with test_size=0.2 and a random_state of 101.**

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=101)

# %% [markdown]
# ## Normalizing the Data
#
# **TASK: Use a MinMaxScaler to normalize the feature data X_train and X_test. Recall we don't want data leakge from the test set so we only fit on the X_train data.**

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()

# %%
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %% [markdown]
# # Creating the Model
#
# **TASK: Run the cell below to import the necessary Keras functions.**
#
#     # For a binary classification problem
#     model.compile(optimizer='rmsprop' or 'adam',
#                   loss='binary_crossentropy',
#                   metrics=['accuracy','precision','recall','f1-score'])

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation,Dropout
from tensorflow.keras.callbacks import EarlyStopping

# %%
X_train.shape
# Out:
# (316824, 77)

# %% [markdown]
# **TASK: Build a sequential model to will be trained on the data. You have unlimited options here, but here is what the solution uses: a model that goes 77 --> 39 --> 19--> 1 output neuron. OPTIONAL: Explore adding  [1](https://en.wikipedia.org/wiki/Dropout_(neural_networks)) [2](https://towardsdatascience.com/machine-learning-part-20-dropout-keras-layers-explained-8c9f6dc4c9ab)**

# %%
model = Sequential()
# Choose whatever number of layers/neurons you want.
# https://stats.stackexchange.com/questions/181/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-netw
model.add(Dense(units=77,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(units=39,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=19,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(units=1,activation='sigmoid'))
# Remember to compile()
model.compile(loss='binary_crossentropy', optimizer='adam')

# %% [markdown]
# Early Stopping

# %%
early_stop = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=20)

# %% [markdown]
# # Examine the class label imbalance
# https://www.tensorflow.org/tutorials/structured_data/imbalanced_data

# %%
neg, pos = np.bincount(y)
total = neg + pos
print('Examples:\n    Total: {}\n    Positive: {} ({:.2f}% of total)\n'.format(
    total, pos, 100 * pos / total))
# Out:
# Examples:
#     Total: 396030
#     Positive: 318357 (80.39% of total)

# %% [markdown]
# Calculate class weights

# %%
# Scaling by total/2 helps keep the loss to a similar magnitude.
# The sum of the weights of all examples stays the same.

alpha=1.5
weight_for_0 = alpha*(1 / neg)*(total)/2.0 
weight_for_1 = (1/alpha)*(1 / pos)*(total)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}


print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Weight for class 0: 3.82
# Weight for class 1: 0.41

# %% [markdown]
# # MODEL 1

# %% [markdown]
# **TASK: Fit the model to the training data for at least 25 epochs. Also add in the validation data for later plotting. Optional: add in a batch_size of 256.**

# %%
model.fit(x=X_train, 
          y=y_train,
          batch_size=256,
          epochs=200,
          validation_data=(X_test, y_test), verbose=1,
          callbacks=[early_stop],
          class_weight=class_weight
          )
# Out:
# Epoch 1/200
# 1238/1238 [==============================] - 5s 3ms/step - loss: 0.5505 - val_loss: 0.5642
# Epoch 2/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.4090 - val_loss: 0.5627
# Epoch 3/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.4001 - val_loss: 0.5611
# Epoch 4/200
# 1238/1238 [==============================] - 3s 3ms/step - loss: 0.3971 - val_loss: 0.5825
# Epoch 5/200
# 1238/1238 [==============================] - 3s 3ms/step - loss: 0.3970 - val_loss: 0.5646
# Epoch 6/200
# 1238/1238 [==============================] - 3s 3ms/step - loss: 0.3947 - val_loss: 0.5751
# Epoch 7/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3948 - val_loss: 0.5907
# Epoch 8/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3928 - val_loss: 0.5593
# Epoch 9/200
# 1238/1238 [==============================] - 3s 3ms/step - loss: 0.3920 - val_loss: 0.5939
# Epoch 10/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3934 - val_loss: 0.5734
# Epoch 11/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3909 - val_loss: 0.5708
# Epoch 12/200
# 1238/1238 [==============================] - 3s 3ms/step - loss: 0.3926 - val_loss: 0.5836
# Epoch 13/200
# 1238/1238 [==============================] - 3s 3ms/step - loss: 0.3916 - val_loss: 0.5673
# Epoch 14/200
# 1238/1238 [==============================] - 3s 3ms/step - loss: 0.3905 - val_loss: 0.5531
# Epoch 15/200
# 1238/1238 [==============================] - 3s 3ms/step - loss: 0.3893 - val_loss: 0.5619
# Epoch 16/200
# 1238/1238 [==============================] - 3s 3ms/step - loss: 0.3921 - val_loss: 0.5711
# Epoch 17/200
# 1238/1238 [==============================] - 3s 3ms/step - loss: 0.3924 - val_loss: 0.5676
# Epoch 18/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3913 - val_loss: 0.5533
# Epoch 19/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3897 - val_loss: 0.5530
# Epoch 20/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3901 - val_loss: 0.5456
# Epoch 21/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3881 - val_loss: 0.5790
# Epoch 22/200
# 1238/1238 [==============================] - 3s 3ms/step - loss: 0.3897 - val_loss: 0.5634
# Epoch 23/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3907 - val_loss: 0.5773
# Epoch 24/200
# 1238/1238 [==============================] - 3s 3ms/step - loss: 0.3878 - val_loss: 0.5912
# Epoch 25/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3886 - val_loss: 0.5633
# Epoch 26/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3875 - val_loss: 0.5576
# Epoch 27/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3898 - val_loss: 0.5505
# Epoch 28/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3887 - val_loss: 0.5476
# Epoch 29/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3867 - val_loss: 0.5824
# Epoch 30/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3863 - val_loss: 0.5568
# Epoch 31/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3846 - val_loss: 0.5990
# Epoch 32/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3859 - val_loss: 0.5848
# Epoch 33/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3887 - val_loss: 0.5616
# Epoch 34/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3862 - val_loss: 0.5554
# Epoch 35/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3843 - val_loss: 0.5554
# Epoch 36/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3878 - val_loss: 0.5682
# Epoch 37/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3853 - val_loss: 0.5739
# Epoch 38/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3872 - val_loss: 0.5623
# Epoch 39/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3861 - val_loss: 0.5643
# Epoch 40/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.3876 - val_loss: 0.5529
# Epoch 00040: early stopping

# %% [markdown]
# **TASK: OPTIONAL: Save your model.**

# %%
from tensorflow.keras.models import load_model

# %%
model.save('model_1_LendingClub.h5')  # creates a HDF5 file 'my_model.h5'

# %%
# later_model = load_model('model_1_LendingClub.h5')

# %% [markdown]
# # Section 3: Evaluating Model Performance.
#
# **TASK: Plot out the validation loss versus the training loss.**

# %%
model_loss = pd.DataFrame(model.history.history)
model_loss.plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# High variance!

# %% [markdown]
# **TASK: Create predictions from the X_test set and display a classification report and confusion matrix for the X_test set.**

# %%
train_predictions_1=model.predict_classes(X_train)
test_predictions_1=model.predict_classes(X_test)
# Out:
# C:\Users\xps-haydo\anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,test_predictions_1))
print('\n')
print(confusion_matrix(y_test,test_predictions_1))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.35      0.92      0.50     15493
#            1       0.97      0.58      0.72     63713
#
#     accuracy                           0.65     79206
#    macro avg       0.66      0.75      0.61     79206
# weighted avg       0.85      0.65      0.68     79206
#
#
#
# [[14230  1263]
#  [26843 36870]]

# %% [markdown]
# Recall for 0 and precision for 1 are better in model1!

# %% [markdown]
# # MODEL 2

# %% [markdown]
# This model does not have weights and is better at predicting for class 1

# %%
model2 = Sequential()
# Choose whatever number of layers/neurons you want.
# https://stats.stackexchange.com/questions/181/how-to-choose-the-number-of-hidden-layers-and-nodes-in-a-feedforward-neural-netw
model2.add(Dense(units=77,activation='relu'))
model2.add(Dropout(0.1))
model2.add(Dense(units=39,activation='relu'))
model2.add(Dropout(0.2))
model2.add(Dense(units=19,activation='relu'))
model2.add(Dropout(0.2))
model2.add(Dense(units=1,activation='sigmoid'))
# Remember to compile()
model2.compile(loss='binary_crossentropy', optimizer='adam')

# %%
model2.fit(x=X_train, 
          y=y_train,
          batch_size=256,
          epochs=200,
          validation_data=(X_test, y_test), verbose=1,
          callbacks=[early_stop]
          )
# Out:
# Epoch 1/200
# 1238/1238 [==============================] - 4s 3ms/step - loss: 0.3764 - val_loss: 0.2789
# Epoch 2/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2846 - val_loss: 0.2771
# Epoch 3/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2802 - val_loss: 0.2764
# Epoch 4/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2807 - val_loss: 0.2760
# Epoch 5/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2768 - val_loss: 0.2771
# Epoch 6/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2786 - val_loss: 0.2760
# Epoch 7/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2776 - val_loss: 0.2758
# Epoch 8/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2768 - val_loss: 0.2759
# Epoch 9/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2765 - val_loss: 0.2756
# Epoch 10/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2759 - val_loss: 0.2756
# Epoch 11/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2768 - val_loss: 0.2756
# Epoch 12/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2762 - val_loss: 0.2754
# Epoch 13/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2771 - val_loss: 0.2750
# Epoch 14/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2738 - val_loss: 0.2751
# Epoch 15/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2732 - val_loss: 0.2749
# Epoch 16/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2750 - val_loss: 0.2752
# Epoch 17/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2730 - val_loss: 0.2753
# Epoch 18/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2739 - val_loss: 0.2750
# Epoch 19/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2731 - val_loss: 0.2751
# Epoch 20/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2743 - val_loss: 0.2753
# Epoch 21/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2728 - val_loss: 0.2761
# Epoch 22/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2705 - val_loss: 0.2749
# Epoch 23/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2735 - val_loss: 0.2752
# Epoch 24/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2719 - val_loss: 0.2753
# Epoch 25/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2727 - val_loss: 0.2750
# Epoch 26/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2725 - val_loss: 0.2750
# Epoch 27/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2725 - val_loss: 0.2756
# Epoch 28/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2718 - val_loss: 0.2751
# Epoch 29/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2696 - val_loss: 0.2753
# Epoch 30/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2699 - val_loss: 0.2756
# Epoch 31/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2708 - val_loss: 0.2752
# Epoch 32/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2715 - val_loss: 0.2750
# Epoch 33/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2709 - val_loss: 0.2758
# Epoch 34/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2705 - val_loss: 0.2750
# Epoch 35/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2729 - val_loss: 0.2754
# Epoch 36/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2697 - val_loss: 0.2754
# Epoch 37/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2693 - val_loss: 0.2754
# Epoch 38/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2707 - val_loss: 0.2755
# Epoch 39/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2698 - val_loss: 0.2752
# Epoch 40/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2699 - val_loss: 0.2759
# Epoch 41/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2701 - val_loss: 0.2751
# Epoch 42/200
# 1238/1238 [==============================] - 3s 2ms/step - loss: 0.2697 - val_loss: 0.2753
# Epoch 00042: early stopping

# %%
model_loss2 = pd.DataFrame(model2.history.history)
model_loss2.plot()
# Out:
# <AxesSubplot:>

# %%
model2.save('model_2_LendingClub.h5')  # creates a HDF5 file 'my_model.h5'

# %%
# later_model = load_model('model_2_LendingClub.h5')

# %% [markdown]
# **TASK: Create predictions from the X_test set and display a classification report and confusion matrix for the X_test set.**

# %%
train_predictions_2=model2.predict_classes(X_train)
test_predictions_2=model2.predict_classes(X_test)
# Out:
# C:\Users\xps-haydo\anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(classification_report(y_test,test_predictions_2))
print('\n')
print(confusion_matrix(y_test,test_predictions_2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.45      0.61     15493
#            1       0.88      1.00      0.94     63713
#
#     accuracy                           0.89     79206
#    macro avg       0.93      0.72      0.77     79206
# weighted avg       0.90      0.89      0.87     79206
#
#
#
# [[ 6910  8583]
#  [  219 63494]]

# %% [markdown]
# # ENSEMBLED MODEL

# %%
from sklearn.linear_model import LogisticRegression
logmodel =LogisticRegression()

y1=model.predict(X_train)
y2=model2.predict(X_train)

# %%
model1_pred = pd.DataFrame(data=y1.reshape(-1,1), index=y_train.index, columns=['Model1'])
model2_pred = pd.DataFrame(data=y2.reshape(-1,1), index=y_train.index, columns=['Model2'])
models_pred = pd.concat([model1_pred,model2_pred, y_train],axis=1)

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(data=models_pred,x="Model1",y="Model2",hue="loan_repaid", alpha=0.3)
# Out:
# <AxesSubplot:xlabel='Model1', ylabel='Model2'>

# %% [markdown]
# Graph does not look promissing. Let's try to ensemble the two models anyway!

# %%
X_ensemble=models_pred.drop('loan_repaid',axis=1)

# %%
X_ensemble=pd.concat([X_ensemble,X_ensemble['Model1']*X_ensemble['Model2'],X_ensemble['Model1']**2,X_ensemble['Model2']**2 ],axis=1)

# %%
X_ensemble
# Out:
#           Model1    Model2         0    Model1    Model2
# 141604  0.311320  0.838354  0.260996  0.096920  0.702838
# 133450  0.398930  0.865204  0.345156  0.159146  0.748578
# 276630  0.303437  0.846570  0.256881  0.092074  0.716680
# 311330  0.840614  0.986288  0.829088  0.706633  0.972763
# 60871   0.559448  0.917805  0.513465  0.312982  0.842366
# ...          ...       ...       ...       ...       ...
# 311895  1.000000  1.000000  1.000000  1.000000  1.000000
# 136767  1.000000  1.000000  1.000000  1.000000  1.000000
# 204614  0.641983  0.947599  0.608343  0.412143  0.897944
# 214539  0.609025  0.935620  0.569817  0.370912  0.875386
# 176991  0.612620  0.928028  0.568528  0.375303  0.861235
#
# [316824 rows x 5 columns]

# %%
logmodel.fit(X_ensemble,y_train)
train_predictions_ensemble=logmodel.predict(X_ensemble)

# %%
pd.concat([models_pred,pd.DataFrame(train_predictions_ensemble, index=y_train.index, columns=['Ensemble'])],axis=1)
# Out:
#           Model1    Model2  loan_repaid  Ensemble
# 141604  0.311320  0.838354            1         1
# 133450  0.398930  0.865204            1         1
# 276630  0.303437  0.846570            1         1
# 311330  0.840614  0.986288            1         1
# 60871   0.559448  0.917805            1         1
# ...          ...       ...          ...       ...
# 311895  1.000000  1.000000            1         1
# 136767  1.000000  1.000000            1         1
# 204614  0.641983  0.947599            1         1
# 214539  0.609025  0.935620            1         1
# 176991  0.612620  0.928028            1         1
#
# [316824 rows x 4 columns]

# %%
models_pred = pd.concat([models_pred,pd.DataFrame(train_predictions_ensemble, index=y_train.index, columns=['Ensemble'])],axis=1)
plt.figure(figsize=(15,15))
sns.scatterplot(data=models_pred,x="Model1",y="Model2",hue="Ensemble", alpha=0.3)
# Out:
# <AxesSubplot:xlabel='Model1', ylabel='Model2'>

# %%
y1=model.predict(X_test)
y2=model2.predict(X_test)
model1_pred = pd.DataFrame(data=y1.reshape(-1,1), index=y_test.index, columns=['Model1'])
model2_pred = pd.DataFrame(data=y2.reshape(-1,1), index=y_test.index, columns=['Model2'])
models_pred = pd.concat([model1_pred,model2_pred],axis=1)
X_ensemble=models_pred
X_ensemble=pd.concat([X_ensemble,X_ensemble['Model1']*X_ensemble['Model2'],X_ensemble['Model1']**2,X_ensemble['Model2']**2 ],axis=1)

test_predictions_ensemble=logmodel.predict(X_ensemble)

train_labels=y_train
test_labels=y_test

# %%
print(classification_report(y_test,test_predictions_ensemble))
print('\n')
print(confusion_matrix(y_test,test_predictions_ensemble))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.48      0.63     15493
#            1       0.89      0.99      0.93     63713
#
#     accuracy                           0.89     79206
#    macro avg       0.89      0.73      0.78     79206
# weighted avg       0.89      0.89      0.87     79206
#
#
#
# [[ 7444  8049]
#  [  800 62913]]

# %% [markdown]
# Ensembling did not improve model 1 as we expected from the graph.

# %% [markdown]
# # Plot the ROC
#
# Now plot the ROC. This plot is useful because it shows, at a glance, the range of performance the model can reach just by tuning the output threshold.

# %%
import sklearn

def plot_roc(name, labels, predictions, **kwargs):
    fp, tp, _ = sklearn.metrics.roc_curve(labels, predictions)

    plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
    plt.xlabel('False positives [%]')
    plt.ylabel('True positives [%]')
#     plt.xlim([-0.5,20])
#     plt.ylim([80,100.5])
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

# %%
plt.figure(figsize=(16,12))
plot_roc("Train Ensemble", train_labels, train_predictions_ensemble, color="red")
plot_roc("Test Ensemble", test_labels, test_predictions_ensemble, color="red", linestyle='--')

plot_roc("Train 1", train_labels, train_predictions_1, color="blue")
plot_roc("Test 1", test_labels, test_predictions_1, color="blue", linestyle='--')

plot_roc("Train 2", train_labels, train_predictions_2, color="green")
plot_roc("Test 2", test_labels, test_predictions_2, color="green", linestyle='--')

plt.legend(loc='lower right')

# %% [markdown]
# **TASK: Given the customer below, would you offer this person a loan?**

# %%
import random
random.seed(101)
random_ind = random.randint(0,len(df))

new_customer = df.drop('loan_repaid',axis=1).iloc[random_ind]
new_customer
# Out:
# loan_amnt            24000
# term                    60
# int_rate             13.11
# installment         547.43
# annual_inc           85000
#                      ...
# 4                        0
# 7                        0
# 8                        0
# 9                        0
# earliest_cr_year      1991
# Name: 304691, Length: 77, dtype: object

# %%
new_customer = scaler.transform(new_customer.values.reshape(-1, len(new_customer)))

# %%
model_ensmble_prediction=((model.predict(new_customer) + model2.predict(new_customer))*0.5 > 0.5)*1

print("Predictions:")
print("Model 1:", model.predict_classes(new_customer))
print("Model 2:", model2.predict_classes(new_customer))
print("Model Ensemble:", model_ensmble_prediction)
# Out:
# Predictions:
# Model 1: [[1]]
# Model 2: [[1]]
# Model Ensemble: [[1]]
# C:\Users\xps-haydo\anaconda3\lib\site-packages\tensorflow\python\keras\engine\sequential.py:450: UserWarning: `model.predict_classes()` is deprecated and will be removed after 2021-01-01. Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
#   warnings.warn('`model.predict_classes()` is deprecated and '

# %% [markdown]
# **TASK: Now check, did this person actually end up paying back their loan?**

# %%
df['loan_repaid'].iloc[random_ind]
# Out:
# 1
